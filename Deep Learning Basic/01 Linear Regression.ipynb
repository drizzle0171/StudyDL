# %% [markdown]
# # 1. Linear Regression

# %%
import torch
from torch import optim

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
w = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)
y_hat = x_train*w+b

# %%
cost = torch.mean((y_hat-y_train)**2)

# %%
optimizer = optim.SGD([w, b], lr=0.01)

nb_epochs = 1000
for epoch in range(1, nb_epochs+1):
  y_hat = x_train*w+b
  cost = torch.mean((y_hat-y_train)**2)

  optimizer.zero_grad() # gradient 초기화
  cost.backward() # gradient 계산
  optimizer.step() # 개선

# %% [markdown]
# # 2. GD

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
w = torch.zeros(1, requires_grad=True)
lr = 0.01
print(w)
# Out:
# tensor([0.], requires_grad=True)

# %%
nb_epochs = 50
for epoch in range(nb_epochs+1):
    y_hat = x_train*w
    cost = torch.mean((y_hat - y_train)**2)
    gradient = torch.sum((w*x_train-y_train)*x_train) #gradient 계산
    print('Epoch {:4d}/{} w: {:.3f}, cost: {:.6f}'.format(
        epoch, nb_epochs, w.item(), cost.item()
    ))
    w = w - lr * gradient
# Out:
# Epoch    0/50 w: 0.000, cost: 18.666666
# Epoch    1/50 w: 0.280, cost: 13.805866
# Epoch    2/50 w: 0.521, cost: 10.210819
# Epoch    3/50 w: 0.728, cost: 7.551922
# Epoch    4/50 w: 0.906, cost: 5.585401
# Epoch    5/50 w: 1.059, cost: 4.130963
# Epoch    6/50 w: 1.191, cost: 3.055260
# Epoch    7/50 w: 1.304, cost: 2.259670
# Epoch    8/50 w: 1.402, cost: 1.671252
# Epoch    9/50 w: 1.485, cost: 1.236058
# Epoch   10/50 w: 1.557, cost: 0.914189
# Epoch   11/50 w: 1.619, cost: 0.676134
# Epoch   12/50 w: 1.673, cost: 0.500069
# Epoch   13/50 w: 1.718, cost: 0.369851
# Epoch   14/50 w: 1.758, cost: 0.273542
# Epoch   15/50 w: 1.792, cost: 0.202312
# Epoch   16/50 w: 1.821, cost: 0.149630
# Epoch   17/50 w: 1.846, cost: 0.110666
# Epoch   18/50 w: 1.868, cost: 0.081849
# Epoch   19/50 w: 1.886, cost: 0.060535
# Epoch   20/50 w: 1.902, cost: 0.044772
# Epoch   21/50 w: 1.916, cost: 0.033113
# Epoch   22/50 w: 1.928, cost: 0.024491
# Epoch   23/50 w: 1.938, cost: 0.018113
# Epoch   24/50 w: 1.946, cost: 0.013397
# Epoch   25/50 w: 1.954, cost: 0.009908
# Epoch   26/50 w: 1.960, cost: 0.007328
# Epoch   27/50 w: 1.966, cost: 0.005420
# Epoch   28/50 w: 1.971, cost: 0.004008
# Epoch   29/50 w: 1.975, cost: 0.002965
# Epoch   30/50 w: 1.978, cost: 0.002193
# Epoch   31/50 w: 1.981, cost: 0.001622
# Epoch   32/50 w: 1.984, cost: 0.001199
# Epoch   33/50 w: 1.986, cost: 0.000887
# Epoch   34/50 w: 1.988, cost: 0.000656
# Epoch   35/50 w: 1.990, cost: 0.000485
# Epoch   36/50 w: 1.991, cost: 0.000359
# Epoch   37/50 w: 1.992, cost: 0.000265
# Epoch   38/50 w: 1.994, cost: 0.000196
# Epoch   39/50 w: 1.994, cost: 0.000145
# Epoch   40/50 w: 1.995, cost: 0.000107
# Epoch   41/50 w: 1.996, cost: 0.000079
# Epoch   42/50 w: 1.996, cost: 0.000059
# Epoch   43/50 w: 1.997, cost: 0.000043
# Epoch   44/50 w: 1.997, cost: 0.000032
# Epoch   45/50 w: 1.998, cost: 0.000024
# Epoch   46/50 w: 1.998, cost: 0.000018
# Epoch   47/50 w: 1.998, cost: 0.000013
# Epoch   48/50 w: 1.999, cost: 0.000010
# Epoch   49/50 w: 1.999, cost: 0.000007
# Epoch   50/50 w: 1.999, cost: 0.000005

# %%
#torch.optim으로 gradient descent 쓰기

x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
w = torch.zeros(1, requires_grad=True)
optimizer = optim.SGD([w], lr=0.15)

# %%
nb_epochs = 30
for epoch in range(nb_epochs+1):
  y_hat = x_train*w
  cost=torch.mean((y_hat-y_train)**2)
  print('Epoch {:4d}/{} w: {:.3f}, cost: {:.6f}'.format(
        epoch, nb_epochs, w.item(), cost.item()
    ))
  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

  #optim을 쓰니까 훨씬 빨리 최적화가 된다!
# Out:
# Epoch    0/30 w: 0.000, cost: 18.666666
# Epoch    1/30 w: 2.800, cost: 2.986668
# Epoch    2/30 w: 1.680, cost: 0.477867
# Epoch    3/30 w: 2.128, cost: 0.076459
# Epoch    4/30 w: 1.949, cost: 0.012233
# Epoch    5/30 w: 2.020, cost: 0.001957
# Epoch    6/30 w: 1.992, cost: 0.000313
# Epoch    7/30 w: 2.003, cost: 0.000050
# Epoch    8/30 w: 1.999, cost: 0.000008
# Epoch    9/30 w: 2.001, cost: 0.000001
# Epoch   10/30 w: 2.000, cost: 0.000000
# Epoch   11/30 w: 2.000, cost: 0.000000
# Epoch   12/30 w: 2.000, cost: 0.000000
# Epoch   13/30 w: 2.000, cost: 0.000000
# Epoch   14/30 w: 2.000, cost: 0.000000
# Epoch   15/30 w: 2.000, cost: 0.000000
# Epoch   16/30 w: 2.000, cost: 0.000000
# Epoch   17/30 w: 2.000, cost: 0.000000
# Epoch   18/30 w: 2.000, cost: 0.000000
# Epoch   19/30 w: 2.000, cost: 0.000000
# Epoch   20/30 w: 2.000, cost: 0.000000
# Epoch   21/30 w: 2.000, cost: 0.000000
# Epoch   22/30 w: 2.000, cost: 0.000000
# Epoch   23/30 w: 2.000, cost: 0.000000
# Epoch   24/30 w: 2.000, cost: 0.000000
# Epoch   25/30 w: 2.000, cost: 0.000000
# Epoch   26/30 w: 2.000, cost: 0.000000
# Epoch   27/30 w: 2.000, cost: 0.000000
# Epoch   28/30 w: 2.000, cost: 0.000000
# Epoch   29/30 w: 2.000, cost: 0.000000
# Epoch   30/30 w: 2.000, cost: 0.000000
